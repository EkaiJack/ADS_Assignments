# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#Checking if any Column's has NA or Missing Values
df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
#Checking for column(s) data-types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # Sample Socio-Demographic Effect on Attrition

# %%
age_effect = df.groupby('Attrition').mean()['Age']
age_effect
#The average age of employees who are lost by attrition is 33.61
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
dist_effect = df.groupby('Attrition').mean()['DistanceFromHome']
dist_effect
# The average distance from home for those who exited the company through attrition was higher at (10.63)
# Out:
# Attrition
# No      8.915653
# Yes    10.632911
# Name: DistanceFromHome, dtype: float64

# %%
MonthlyIncome_effect = df.groupby('Attrition').mean()['MonthlyIncome']
MonthlyIncome_effect
  #Employees who exited the company through atrrition had a lower average monthly Income.
# Out:
# Attrition
# No     6832.739659
# Yes    4787.092827
# Name: MonthlyIncome, dtype: float64

# %%
GenderEffect = pd.crosstab(df['Gender'],df['Attrition'], margins = False, normalize='columns')
GenderEffect
#Larger percentage of those who left the company are Male Employees.
# Out:
# Attrition        No       Yes
# Gender
# Female     0.406326  0.367089
# Male       0.593674  0.632911

# %% [markdown]
# # A breakdown of distance from home by job role and attrition.

# %%
df.groupby(["JobRole","Attrition"]).describe() ["DistanceFromHome"]
# Out:
#                                      count       mean        std  min    25%  \
# JobRole                   Attrition
# Healthcare Representative No         122.0   9.204918   7.989599  1.0   2.00
#                           Yes          9.0  17.666667   8.093207  2.0  14.00
# Human Resources           No          40.0   6.600000   6.934862  1.0   2.00
#                           Yes         12.0  13.416667   8.005207  1.0   7.50
# Laboratory Technician     No         197.0   9.329949   8.101887  1.0   2.00
#                           Yes         62.0   9.661290   8.036685  1.0   3.00
# Manager                   No          97.0   7.927835   8.223756  1.0   2.00
#                           Yes          5.0  10.000000  12.020815  2.0   2.00
# Manufacturing Director    No         135.0   9.533333   8.725328  1.0   2.00
#                           Yes         10.0   8.800000   7.955431  1.0   2.25
# Research Director         No          78.0   8.474359   7.589679  1.0   2.00
# ...

# %% [markdown]
# # Comparison of average monthly income by education and attrition.

# %%
df.groupby(["Education","Attrition"]).mean() ["MonthlyIncome"]
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# # Assignment 3
#
#  ## Visualization on breakdown of distance from home by job role and attrition.

# %%
sb.catplot(x="Attrition", y="DistanceFromHome", hue="JobRole", data=df, kind="box")

# %% [markdown]
# ### Visualization on the comparison of average monthly income by education and attrition.

# %%
sb.catplot(x="Attrition", y="MonthlyIncome", hue="Education", data=df, kind="bar")
